# %% [markdown]
# # **Homework 8 - Anomaly Detection**
#
# If there are any questions, please contact mlta-2022spring-ta@googlegroups.com
#
# Slide:    [Link]()　Kaggle: [Link](https://www.kaggle.com/c/ml2022spring-hw8)

# %% [markdown]
# # Set up the environment

# %% [markdown]
# ## Package installation

# %%
# Training progress bar
# !pip install -q qqdm

# %% [markdown]
# ## Downloading data

# %%
# !wget https://github.com/MachineLearningHW/HW8_Dataset/releases/download/v1.0.0/data.zip

# %%
# !nvidia-smi
# Out:
# Sat May  7 14:51:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  On   | 00000000:1B:00.0 Off |                  N/A |
# | 30%   35C    P8     3W / 225W |  10090MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:1C:00.0 Off |                  N/A |
# | 29%   65C    P2   221W / 225W |   9342MiB / 11019MiB |     82%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:1D:00.0 Off |                  N/A |
# | 36%   62C    P2   160W / 225W |   6742MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  On   | 00000000:1E:00.0 Off |                  N/A |
# | 36%   62C    P2   179W / 225W |   4778MiB / 11019MiB |     18%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 208...  On   | 00000000:3D:00.0 Off |                  N/A |
# | 30%   28C    P8     1W / 225W |   2018MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 208...  On   | 00000000:3F:00.0 Off |                  N/A |
# | 42%   65C    P2   137W / 225W |  10845MiB / 11019MiB |     89%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 208...  On   | 00000000:40:00.0 Off |                  N/A |
# | 29%   32C    P8     3W / 225W |      3MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce RTX 208...  On   | 00000000:41:00.0 Off |                  N/A |
# | 48%   66C    P2   181W / 225W |   8848MiB / 11019MiB |     69%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1918      C   ...nda3/envs/unet/bin/python      153MiB |
# |    0   N/A  N/A     45085      C   ...envs/bev1.8/bin/python3.7      991MiB |
# |    0   N/A  N/A     51892      C   .../deep-burst-sr/bin/python     8943MiB |
# |    1   N/A  N/A     49497      C   python3                          9339MiB |
# |    2   N/A  N/A     18468      C   python                           6739MiB |
# |    3   N/A  N/A     18468      C   python                           4775MiB |
# |    4   N/A  N/A     45085      C   ...envs/bev1.8/bin/python3.7     2015MiB |
# |    5   N/A  N/A     37966      C   ...nda3/envs/unet/bin/python     1747MiB |
# |    5   N/A  N/A     50742      C   python                           9095MiB |
# |    7   N/A  N/A     15533      C   python                           8845MiB |
# +-----------------------------------------------------------------------------+

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "6"

# %%
 # !unzip data.zip

# %%
# from shutil import copyfile
# copyfile(src = "../input/hw8-data/testingset.npy", dst = "./testingset.npy")
# copyfile(src = "../input/hw8-data/trainingset.npy", dst = "./trainingset.npy")

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (0.11.2)
# Requirement already satisfied: torch==1.10.1 in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from torchvision) (1.10.1)
# Requirement already satisfied: numpy in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from torchvision) (1.19.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: dataclasses in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from torch==1.10.1->torchvision) (0.8)
# Requirement already satisfied: typing-extensions in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from torch==1.10.1->torchvision) (4.0.1)

# %% [markdown]
# # Import packages

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.15.4 in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /auto/master10/yuehchi/.local/share/virtualenvs/yuehchi-eZPBS6yr/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
import random
import numpy as np
import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.models as models
from torch.optim import Adam, AdamW
from qqdm import qqdm, format_str
import pandas as pd

# %% [markdown]
# # Loading data

# %%
train = np.load('data/trainingset.npy', allow_pickle=True)
test = np.load('data/testingset.npy', allow_pickle=True)

print(train.shape)
print(test.shape)
# Out:
# (100000, 64, 64, 3)
# (19636, 64, 64, 3)

# %% [markdown]
# ## Random seed
# Set the random seed to a certain value for reproducibility.

# %%
def same_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

same_seeds(14132)

# %% [markdown]
# # Autoencoder

# %% [markdown]
# # Models & loss

# %%
class fcn_autoencoder(nn.Module):
    def __init__(self):
        super(fcn_autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(64 * 64 * 3, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(), 
            nn.Linear(64, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        
        self.encoder1 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(), 
            nn.Linear(64, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        
        self.encoder2 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 2048),
            nn.ReLU(),
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        self.encoder4 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 300),
            nn.ReLU(),
            nn.Linear(300, 256),
            nn.ReLU(), 
            nn.Linear(256, 128), 
            nn.ReLU(), 
            nn.Linear(128, 64), 
            nn.ReLU(), 
            nn.Linear(64, 32), 
            nn.ReLU(), 
            nn.Linear(32, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        self.encoder5 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),   
            nn.Linear(64, 32),
            nn.ReLU(), 
            nn.Linear(32, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        
        self.encoder6 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 12),
            nn.ReLU(),
            nn.Linear(12, 3)
        )
        self.encoder7 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 256),
            nn.ReLU(),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, 16),
            nn.ReLU(),
            nn.Linear(16, 12),
            nn.ReLU(),
            nn.Linear(12, 3)
        )
            
        self.encoder8 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 256),
            nn.ReLU(),
            nn.Linear(256, 184),
            nn.ReLU(),
            nn.Linear(184, 92),
            nn.ReLU(),
            nn.Linear(92, 48),
            nn.ReLU(),
            nn.Linear(48, 12),
            nn.ReLU(),
            nn.Linear(12, 3)
        )
        self.encoder9 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(), 
            nn.Linear(32, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        
        self.encoder10 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(), 
            nn.Linear(32, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        
        
        self.encoder11 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 250),
            nn.ReLU(),
            nn.Linear(250, 150),
            nn.ReLU(),
            nn.Linear(150, 128),
            nn.ReLU(),
            nn.Linear(128, 84),
            nn.ReLU(),
            nn.Linear(84, 48),
            nn.ReLU(), 
            nn.Linear(48, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )
        
        self.encoder12 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 300),
            nn.ReLU(),
            nn.Linear(300, 200),
            nn.ReLU(),
            nn.Linear(200, 100),
            nn.ReLU(),
            nn.Linear(100, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(), 
            nn.Linear(32, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )


        self.encoder13 = nn.Sequential(
            nn.Linear(64 * 64 * 3, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 48),
            nn.ReLU(),
            nn.Linear(48, 12), 
            nn.ReLU(), 
            nn.Linear(12, 3)
        )

        self.decoder = nn.Sequential(
            nn.Linear(39, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 150),
            nn.ReLU(),
            nn.Linear(150, 252),
            nn.ReLU(),
            nn.Linear(252, 300),
            nn.ReLU(),
            nn.Linear(300, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 64 * 64 * 3), 
            nn.Tanh()
        )


    def forward(self, x):
        x1 = self.encoder(x)
        x2 = self.encoder1(x)
        x3 = self.encoder2(x)
        x4 = self.encoder4(x)
        x5 = self.encoder5(x)
        x6 = self.encoder6(x)
        x7 = self.encoder7(x)
        x8 = self.encoder8(x)
        x9 = self.encoder9(x)
        x10 = self.encoder10(x)
        x11 = self.encoder11(x)
        x12 = self.encoder12(x)
        x13 = self.encoder13(x)
        
        x14 = torch.cat((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13),1)
        # x11 = torch.cat((x1,x4,x7,x8),1)
        x15 = self.decoder(x14)
        return x15


class conv_autoencoder(nn.Module):
    def __init__(self):
        super(conv_autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 12, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(12, 32, 4, stride=2, padding=1),        
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(128, 256, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(256, 512, 4, stride=2, padding=1),  
            nn.ReLU(),
        )    
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 12, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(12, 32, 4, stride=2, padding=1),        
            nn.ReLU(),
            nn.Conv2d(32, 75, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(75, 150, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(150, 300, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(300, 512, 4, stride=2, padding=1),  
            nn.ReLU(),
        )
        self.encoder2 = nn.Sequential(
            nn.Conv2d(3, 12, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(12, 48, 4, stride=2, padding=1),        
            nn.ReLU(),
            nn.Conv2d(48, 96, 4, stride=2, padding=1),         
            nn.ReLU(),
            nn.Conv2d(96, 128, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(128, 256, 4, stride=2, padding=1),  
            nn.ReLU(),
            nn.Conv2d(256, 512, 4, stride=2, padding=1),  
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(512, 256, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 12, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1),
            nn.Tanh(),
        )



    def forward(self, x):
        x1 = self.encoder(x)
        # print(x1.shape)
        x2 = self.encoder1(x)
        # print(x2.shape)
        x3 = self.encoder2(x)
        # print(x3.shape)
        
        x4 = x1+x2+x3
        # print(x4.shape)
        x = self.decoder(x4)
        
        return x


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 12, 4, stride=2, padding=1),            
            nn.ReLU(),
            nn.Conv2d(12, 24, 4, stride=2, padding=1),    
            nn.ReLU(),
        )
        self.enc_out_1 = nn.Sequential(
            nn.Conv2d(24, 48, 4, stride=2, padding=1),  
            nn.ReLU(),
        )
        self.enc_out_2 = nn.Sequential(
            nn.Conv2d(24, 48, 4, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(48, 24, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(24, 12, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1), 
            nn.Tanh(),
        )

    def encode(self, x):
        h1 = self.encoder(x)
        return self.enc_out_1(h1), self.enc_out_2(h1)

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if torch.cuda.is_available():
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparametrize(mu, logvar)
        return self.decode(z), mu, logvar


def loss_vae(recon_x, x, mu, logvar, criterion):
    """
    recon_x: generating images
    x: origin images
    mu: latent mean
    logvar: latent log variance
    """
    mse = criterion(recon_x, x)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.sum(KLD_element).mul_(-0.5)
    return mse + KLD

# %% [markdown]
# # Dataset module
#
# Module for obtaining and processing data. The transform function here normalizes image's pixels from [0, 255] to [-1.0, 1.0].

# %%
class CustomTensorDataset(TensorDataset):
    """TensorDataset with support of transforms.
    """
    def __init__(self, tensors):
        self.tensors = tensors
        if tensors.shape[-1] == 3:
            self.tensors = tensors.permute(0, 3, 1, 2)
        
        self.transform = transforms.Compose([
          transforms.Lambda(lambda x: x.to(torch.float32)),
          transforms.Lambda(lambda x: 2. * x/255. - 1.),
        ])
        
    def __getitem__(self, index):
        x = self.tensors[index]
        
        if self.transform:
            # mapping images to [-1.0, 1.0]
            x = self.transform(x)

        return x

    def __len__(self):
        return len(self.tensors)

# %% [markdown]
# # Training

# %% [markdown]
# ## Configuration

# %%
from torch.optim import lr_scheduler
from torch.optim.lr_scheduler import StepLR
# Training hyperparameters
num_epochs = 512
batch_size = 10000
learning_rate = 1e-3

# Build training dataloader
x = torch.from_numpy(train)
train_dataset = CustomTensorDataset(x)

train_sampler = RandomSampler(train_dataset)
train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=batch_size)
train_num = len(train_dataloader)

# Model
model_type = 'fcn'   # selecting a model type from {'cnn', 'fcn', 'vae', 'resnet'}
model_classes = {'fcn': fcn_autoencoder(), 'cnn': conv_autoencoder(), 'vae': VAE()}
model = model_classes[model_type].cuda()

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# scheduler = lr_scheduler.StepLR(optimizer, step_size= 10, gamma=0.1)
##step_size=args.step_size

# %% [markdown]
# ## Training loop

# %%
best_loss = np.inf
model.train()

qqdm_train = qqdm(range(num_epochs), desc=format_str('bold', 'Description'))
for epoch in qqdm_train:
    tot_loss = list()
    for data in train_dataloader:

        # ===================loading=====================
        img = data.float().cuda()
        if model_type in ['fcn']:
            img = img.view(img.shape[0], -1)

        # ===================forward=====================
        output = model(img)
        if model_type in ['vae']:
            loss = loss_vae(output[0], img, output[1], output[2], criterion)
        else:
            loss = criterion(output, img)

        tot_loss.append(loss.item())
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
#         scheduler.step()
    # ===================save_best====================
    mean_loss = np.mean(tot_loss)
    if mean_loss < best_loss:
        best_loss = mean_loss
        torch.save(model, 'best_model_{}.pt'.format(model_type))
    # ===================log========================
    qqdm_train.set_infos({
        'epoch': f'{epoch + 1:.0f}/{num_epochs:.0f}',
        'loss': f'{mean_loss:.4f}',
    })
    # ===================save_last========================
    torch.save(model, 'last_model_{}.pt'.format(model_type))
# Out:
#  Iters    Elapsed Time      Speed
#  0/512          -             -
# Description   0.0% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  1/512  00:00:17<02:27:51  0.06it/s  1/512  0.3345
# Description   0.2% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  2/512  00:00:34<02:26:06  0.06it/s  2/512  0.2666
# Description   0.4% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  3/512  00:00:51<02:25:52  0.06it/s  3/512  0.2257
# Description   0.6% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  4/512  00:01:09<02:26:04  0.06it/s  4/512  0.2023
# Description   0.8% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  5/512  00:01:26<02:25:38  0.06it/s  5/512  0.1909
# Description   1.0% |                                                                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  6/512  00:01:43<02:25:22  0.06it/s  6/512  0.1839
# Description   1.2% |█                                                                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  7/512  00:02:00<02:24:55  0.06it/s  7/512  0.1806
# Description   1.4% |█                                                                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  8/512  00:02:17<02:24:35  0.06it/s  8/512  0.1786
# Description   1.6% |█                                                                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  9/512  00:02:34<02:23:56  0.06it/s  9/512  0.1773
# Description   1.8% |█                                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  10/512  00:02:51<02:23:14  0.06it/s  10/512  0.1762
# Description   2.0% |█                                                                                                  | Iters     Elapsed Time      Speed    epoch    loss
#  11/512  00:03:07<02:22:19  0.06it/s  11/512  0.1750
# Description   2.1% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  12/512  00:03:24<02:21:50  0.06it/s  12/512  0.1697
# Description   2.3% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  13/512  00:03:41<02:21:32  0.06it/s  13/512  0.1627
# Description   2.5% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  14/512  00:03:57<02:21:01  0.06it/s  14/512  0.1580
# Description   2.7% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  15/512  00:04:14<02:20:32  0.06it/s  15/512  0.1477
# Description   2.9% |██                                                                                                 | Iters     Elapsed Time      Speed    epoch    loss
#  16/512  00:04:31<02:20:12  0.06it/s  16/512  0.1420
# Description   3.1% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  17/512  00:04:48<02:19:57  0.06it/s  17/512  0.1362
# Description   3.3% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  18/512  00:05:05<02:19:42  0.06it/s  18/512  0.1317
# Description   3.5% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  19/512  00:05:22<02:19:20  0.06it/s  19/512  0.1275
# Description   3.7% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  20/512  00:05:39<02:19:02  0.06it/s  20/512  0.1274
# Description   3.9% |███                                                                                                | Iters     Elapsed Time      Speed    epoch    loss
#  21/512  00:05:56<02:18:59  0.06it/s  21/512  0.1227
# Description   4.1% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  22/512  00:06:13<02:18:43  0.06it/s  22/512  0.1199
# Description   4.3% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  23/512  00:06:30<02:18:30  0.06it/s  23/512  0.1192
# Description   4.5% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  24/512  00:06:47<02:18:12  0.06it/s  24/512  0.1171
# Description   4.7% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  25/512  00:07:04<02:17:54  0.06it/s  25/512  0.1157
# Description   4.9% |████                                                                                               | Iters     Elapsed Time      Speed    epoch    loss
#  26/512  00:07:21<02:17:36  0.06it/s  26/512  0.1135
# Description   5.1% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  27/512  00:07:38<02:17:18  0.06it/s  27/512  0.1111
# Description   5.3% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  28/512  00:07:55<02:16:56  0.06it/s  28/512  0.1100
# Description   5.5% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  29/512  00:08:12<02:16:34  0.06it/s  29/512  0.1098
# Description   5.7% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#  30/512  00:08:28<02:16:13  0.06it/s  30/512  0.1081
# Description   5.9% |█████                                                                                              | Iters     Elapsed Time      Speed    epoch    loss
#
|██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  490/512  02:13:33<00:05:59  0.06it/s  490/512  0.0500
# Description  95.7% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  491/512  02:13:49<00:05:43  0.06it/s  491/512  0.0510
# Description  95.9% |██████████████████████████████████████████████████████████████████████████████████████████████     |  Iters     Elapsed Time      Speed     epoch    loss
#  492/512  02:14:05<00:05:27  0.06it/s  492/512  0.0505
# Description  96.1% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  493/512  02:14:21<00:05:10  0.06it/s  493/512  0.0504
# Description  96.3% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  494/512  02:14:37<00:04:54  0.06it/s  494/512  0.0510
# Description  96.5% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  495/512  02:14:53<00:04:37  0.06it/s  495/512  0.0506
# Description  96.7% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  496/512  02:15:09<00:04:21  0.06it/s  496/512  0.0505
# Description  96.9% |███████████████████████████████████████████████████████████████████████████████████████████████    |  Iters     Elapsed Time      Speed     epoch    loss
#  497/512  02:15:25<00:04:05  0.06it/s  497/512  0.0503
# Description  97.1% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  498/512  02:15:40<00:03:48  0.06it/s  498/512  0.0509
# Description  97.3% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  499/512  02:15:56<00:03:32  0.06it/s  499/512  0.0500
# Description  97.5% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  500/512  02:16:12<00:03:16  0.06it/s  500/512  0.0503
# Description  97.7% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  501/512  02:16:28<00:02:59  0.06it/s  501/512  0.0503
# Description  97.9% |████████████████████████████████████████████████████████████████████████████████████████████████   |  Iters     Elapsed Time      Speed     epoch    loss
#  502/512  02:16:44<00:02:43  0.06it/s  502/512  0.0507
# Description  98.0% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  503/512  02:17:01<00:02:27  0.06it/s  503/512  0.0502
# Description  98.2% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  504/512  02:17:18<00:02:10  0.06it/s  504/512  0.0502
# Description  98.4% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  505/512  02:17:33<00:01:54  0.06it/s  505/512  0.0506
# Description  98.6% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  506/512  02:17:49<00:01:38  0.06it/s  506/512  0.0508
# Description  98.8% |█████████████████████████████████████████████████████████████████████████████████████████████████  |  Iters     Elapsed Time      Speed     epoch    loss
#  507/512  02:18:06<00:01:21  0.06it/s  507/512  0.0501
# Description  99.0% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  508/512  02:18:22<00:01:05  0.06it/s  508/512  0.0504
# Description  99.2% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  509/512  02:18:39<00:00:49  0.06it/s  509/512  0.0499
# Description  99.4% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  510/512  02:18:55<00:00:32  0.06it/s  510/512  0.0503
# Description  99.6% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  511/512  02:19:12<00:00:16  0.06it/s  511/512  0.0507
# Description  99.8% |██████████████████████████████████████████████████████████████████████████████████████████████████ |  Iters     Elapsed Time      Speed     epoch    loss
#  512/512  02:19:30<00:00:00  0.06it/s  512/512  0.0506
# Description 100.0% |███████████████████████████████████████████████████████████████████████████████████████████████████|  Iters     Elapsed Time      Speed     epoch    loss
#  512/512  02:19:30<00:00:00  0.06it/s  512/512  0.0506
# Description 100.0% |███████████████████████████████████████████████████████████████████████████████████████████████████|

# %% [markdown]
# # Inference
# Model is loaded and generates its anomaly score predictions.

# %% [markdown]
# ## Initialize
# - dataloader
# - model
# - prediction file

# %%
eval_batch_size = 200

# build testing dataloader
data = torch.tensor(test, dtype=torch.float32)
test_dataset = CustomTensorDataset(data)
test_sampler = SequentialSampler(test_dataset)
test_dataloader = DataLoader(test_dataset, sampler=test_sampler, batch_size=eval_batch_size, num_workers=1)
eval_loss = nn.MSELoss(reduction='none')

# load trained model
checkpoint_path = f'last_model_{model_type}.pt'
model = torch.load(checkpoint_path)
model.eval()

# prediction file 
out_file = 'prediction.csv'

# %%
anomality = list()
with torch.no_grad():
  for i, data in enumerate(test_dataloader):
    img = data.float().cuda()
    if model_type in ['fcn']:
      img = img.view(img.shape[0], -1)
    output = model(img)
    if model_type in ['vae']:
      output = output[0]
    if model_type in ['fcn']:
        loss = eval_loss(output, img).sum(-1)
    else:
        loss = eval_loss(output, img).sum([1, 2, 3])
    anomality.append(loss)
anomality = torch.cat(anomality, axis=0)
anomality = torch.sqrt(anomality).reshape(len(test), 1).cpu().numpy()

df = pd.DataFrame(anomality, columns=['score'])
df.to_csv(out_file, index_label = 'ID')
